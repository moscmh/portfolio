# %% [markdown]
# # [British Airways Job Simulation](https://www.theforage.com/simulations/british-airways/data-science-yqoz)
# ## Predictive modeling of customer bookings
# This project provided a dataset containing customers' information regarding their flight booking experience. The critical information of the dataset is whether the customer actually completed the booking. A predictive model will be built after exploratory data analysis to estimate if a customer would go ahead with the booking based on the given features.
#
# ### Exploratory data analysis

# %%
import importlib
import britishairways_modules
importlib.reload(britishairways_modules)

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('tableau-colorblind10') # mpl.style.available
import seaborn as sns
sns.set_style("white")

from sklearn.model_selection import train_test_split

random_state = 4
np.random.seed(random_state)

# %%
df = pd.read_csv("data/customer_booking.csv", encoding="ISO-8859-1")
print(df.shape)
df.head()
# Out:
# (50000, 14)
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             5.52
# 1                     0                      0             5.52
# 2                     1                      0             5.52
# 3                     0                      1             5.52
# 4                     0                      1             5.52
#
#    booking_complete
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         50000 non-null  int64
#  1   sales_channel          50000 non-null  object
#  2   trip_type              50000 non-null  object
#  3   purchase_lead          50000 non-null  int64
#  4   length_of_stay         50000 non-null  int64
#  5   flight_hour            50000 non-null  int64
#  6   flight_day             50000 non-null  object
#  7   route                  50000 non-null  object
#  8   booking_origin         50000 non-null  object
#  9   wants_extra_baggage    50000 non-null  int64
#  10  wants_preferred_seat   50000 non-null  int64
#  11  wants_in_flight_meals  50000 non-null  int64
#  12  flight_duration        50000 non-null  float64
#  13  booking_complete       50000 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.3+ MB

# %% [markdown]
# To provide more context, below is a more detailed data description, explaining exactly what each column means:
#
# - `num_passengers` = number of passengers travelling
# - `sales_channel` = sales channel booking was made on
# - `trip_type` = trip Type (Round Trip, One Way, Circle Trip)
# - `purchase_lead` = number of days between travel date and booking date
# - `length_of_stay` = number of days spent at destination
# - `flight_hour` = hour of flight departure
# - `flight_day` = day of week of flight departure
# - `route` = origin -> destination flight route
# - `booking_origin` = country from where booking was made
# - `wants_extra_baggage` = if the customer wanted extra baggage in the booking
# - `wants_preferred_seat` = if the customer wanted a preferred seat in the booking
# - `wants_in_flight_meals` = if the customer wanted in-flight meals in the booking
# - `flight_duration` = total duration of flight (in hours)
# - `booking_complete` = flag indicating if the customer completed the booking

# %%
df["flight_day"].unique()
# Out:
# array(['Sat', 'Wed', 'Thu', 'Mon', 'Sun', 'Tue', 'Fri'], dtype=object)

# %%
mapping = {
    "Mon": 1,
    "Tue": 2,
    "Wed": 3,
    "Thu": 4,
    "Fri": 5,
    "Sat": 6,
    "Sun": 7,
}

df["flight_day"] = df["flight_day"].map(mapping)
df["flight_day"].unique()
# Out:
# array([6, 3, 4, 1, 7, 2, 5])

# %%
df['booking_complete'].value_counts()
# Out:
# booking_complete
# 0    42522
# 1     7478
# Name: count, dtype: int64

# %%
df['booking_complete'].value_counts(normalize=True)
# Out:
# booking_complete
# 0    0.85044
# 1    0.14956
# Name: proportion, dtype: float64

# %% [markdown]
# The classes in the target variable is imbalanced. Downsampling on label `0` will be used to balance number of both classes.

# %% [markdown]
# ### Withhold Validation Set

# %%
df_down = pd.concat([
    df.loc[df['booking_complete'] == 0].sample(n=df.loc[df['booking_complete'] == 1].shape[0], random_state=random_state),
    df.loc[df['booking_complete'] == 1]
]).reset_index(drop=True)

df_down.shape
# Out:
# (14956, 14)

# %%
val = df_down.sample(frac=0.2, random_state=random_state)
train = df_down.drop(index=val.index)
val.shape, train.shape
# Out:
# ((2991, 14), (11965, 14))

# %%
train['booking_complete'].value_counts()
# Out:
# booking_complete
# 1    6001
# 0    5964
# Name: count, dtype: int64

# %%
val['booking_complete'].value_counts()
# Out:
# booking_complete
# 0    1514
# 1    1477
# Name: count, dtype: int64

# %%
num_cols = train.select_dtypes(include='number').columns.tolist()
cat_cols = train.select_dtypes(exclude='number').columns.tolist()

# %% [markdown]
# #### Categorical Features

# %%
cat_cols
# Out:
# ['sales_channel', 'trip_type', 'route', 'booking_origin']

# %% [markdown]
# ##### `route`

# %%
def route_grouping(route):
    '''
    Group routes into 5 categories based on ratio of booking completion -
    1. 0-20% - Very Low
    2. 20-40% - Low
    3. 40-60% - Medium
    4. 60-80% - High
    5. 80-100% - Very High
    ----------
    Parameters:
        route (str) : Route labels (e.g. AKLDEL)
    ----------
    Returns:
        str : Group name
    '''
    
    total = df.loc[df['route'] == route, 'booking_complete'].count()
    complete = df.loc[df['route'] == route, 'booking_complete'].sum()
    ratio = complete / total

    if ratio < 0.2:
        return 'Very Low'
    elif ratio < 0.4:
        return 'Low'
    elif ratio < 0.6:
        return 'Medium'
    elif ratio < 0.8:
        return 'High'
    else:
        return 'Very High'

# %%
train['route_group'] = train['route'].apply(route_grouping)
train['route_group'] = train['route_group'].astype('object')

val['route_group'] = val['route'].apply(route_grouping)
val['route_group'] = val['route_group'].astype('object')

train.drop(columns=['route'], inplace=True)
val.drop(columns=['route'], inplace=True)

# %% [markdown]
# ##### `booking_origin`

# %%
def booking_origin_grouping(origin):
    '''
    Group routes into 5 categories based on ratio of booking completion -
    1. 0-20% - Very Low
    2. 20-40% - Low
    3. 40-60% - Medium
    4. 60-80% - High
    5. 80-100% - Very High
    ----------
    Parameters:
        route (origin) : Origin labels (e.g. "New Zealand")
    ----------
    Returns:
        str : Group name
    '''
    
    total = df.loc[df['booking_origin'] == origin, 'booking_complete'].count()
    complete = df.loc[df['booking_origin'] == origin, 'booking_complete'].sum()
    ratio = complete / total

    if ratio < 0.2:
        return 'Very Low'
    elif ratio < 0.4:
        return 'Low'
    elif ratio < 0.6:
        return 'Medium'
    elif ratio < 0.8:
        return 'High'
    else:
        return 'Very High'

# %%
train['booking_origin_group'] = train['booking_origin'].apply(booking_origin_grouping)
train['booking_origin_group'] = train['booking_origin_group'].astype('object')

val['booking_origin_group'] = val['booking_origin'].apply(booking_origin_grouping)
val['booking_origin_group'] = val['booking_origin_group'].astype('object')

train.drop(columns=['booking_origin'], inplace=True)
val.drop(columns=['booking_origin'], inplace=True)

# %% [markdown]
# #### Numeric Features

# %%
train[['num_passengers', 'purchase_lead', 'length_of_stay', 'flight_duration']] = train[['num_passengers', 'purchase_lead', 'length_of_stay', 'flight_duration']].astype('float64')
val[['num_passengers', 'purchase_lead', 'length_of_stay', 'flight_duration']] = val[['num_passengers', 'purchase_lead', 'length_of_stay', 'flight_duration']].astype('float64')

fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()

for i, col in enumerate(train.select_dtypes(include='float64').columns):
    sns.boxplot(train[col], width=.1, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
train[['num_passengers_log', 'purchase_lead_log', 'length_of_stay_log']] = train[['num_passengers', 'purchase_lead', 'length_of_stay']].apply(lambda x: np.log1p(x))
val[['num_passengers_log', 'purchase_lead_log', 'length_of_stay_log']] = val[['num_passengers', 'purchase_lead', 'length_of_stay']].apply(lambda x: np.log1p(x))

# %% [markdown]
# ### Data Preprocessing

# %%
X_train, y_train = train.drop(columns=['booking_complete',
                                       'num_passengers',
                                       'purchase_lead',
                                       'length_of_stay']), train['booking_complete']
X_val, y_val = val.drop(columns=['booking_complete',
                                       'num_passengers',
                                       'purchase_lead',
                                       'length_of_stay']), val['booking_complete']

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
num_cols = train.select_dtypes(include='number').drop(columns=['num_passengers', 'num_passengers_log', 'purchase_lead', 'length_of_stay', 'flight_day', 'wants_extra_baggage', 'wants_preferred_seat', 'wants_in_flight_meals', 'booking_complete']).columns.tolist()
cat_cols = train.select_dtypes(exclude='number').columns.tolist()

# %%
num_cols
# Out:
# ['flight_hour', 'flight_duration', 'purchase_lead_log', 'length_of_stay_log']

# %%
cat_cols
# Out:
# ['sales_channel', 'trip_type', 'route_group', 'booking_origin_group']

# %%
pipe_preprocess = Pipeline(steps=[
    ('preprocessor', ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), num_cols),
            ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols),
            ('cat_extra', OrdinalEncoder(), ['wants_extra_baggage', 'wants_preferred_seat', 'wants_in_flight_meals', 'flight_day'])
        ]
    ))
])

pipe_preprocess.fit(X_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['flight_hour',
#                                                    'flight_duration',
#                                                    'purchase_lead_log',
#                                                    'length_of_stay_log']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['sales_channel', 'trip_type',
#                                                    'route_group',
#                                                    'booking_origin_group']),
#                                                  ('cat_extra', OrdinalEncoder(),
#                                                   ['wants_extra_baggage',
#                                                    'wants_preferred_seat',
#                                                    'wants_in_flight_meals',
#                                                    'flight_day'])]))])

# %%
X_train = pipe_preprocess.transform(X_train)
X_val = pipe_preprocess.transform(X_val)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score, f1_score
import optuna

# 1. Define an objective function to be maximized.
def objective(trial):

    # 2. Suggest values for the hyperparameters using a trial object.
    classifier_name = trial.suggest_categorical('classifier', ['GradientBoosting', 'RandomForest'])
    if classifier_name == 'GradientBoosting':
         gb_loss = trial.suggest_categorical('gb_loss', ['log_loss', 'exponential'])
         gb_learning_rate = trial.suggest_float('gb_learning_rate', .001, 1, log=True)
         gb_n_estimators = trial.suggest_int('gb_n_estimators', 50, 500, step=50)
         gb_subsample = trial.suggest_float('gb_subsample', .1, 1, step=.1)
         gb_criterion = trial.suggest_categorical('gb_criterion', ['friedman_mse', 'squared_error'])
         gb_max_depth = trial.suggest_int('gb_max_depth', 2, 32, log=True)
         classifier_obj = GradientBoostingClassifier(
             loss=gb_loss, 
             learning_rate=gb_learning_rate, 
             n_estimators=gb_n_estimators, 
             subsample=gb_subsample, 
             criterion=gb_criterion, 
             max_depth=gb_max_depth,
             random_state=random_state,
             validation_fraction=0.1,
             n_iter_no_change=10
             )
    else:
        rf_n_estimators = trial.suggest_int('rf_n_estimators', 10, 100, step=10)
        rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32, log=True)
        classifier_obj = RandomForestClassifier(
            max_depth=rf_max_depth, 
            n_estimators=rf_n_estimators,
            random_state=random_state
            )

    classifier_obj.fit(X_train, y_train)
    f1 = f1_score(y_val, classifier_obj.predict(X_val))
    return f1

# 3. Create a study object and optimize the objective function.
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-08-04 23:05:06,828] A new study created in memory with name: no-name-b3a5620f-0192-4a63-8a24-176d89db4f90
# [I 2025-08-04 23:05:06,906] Trial 0 finished with value: 0.7335504885993486 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 50, 'rf_max_depth': 2}. Best is trial 0 with value: 0.7335504885993486.
# [I 2025-08-04 23:05:06,947] Trial 1 finished with value: 0.7278688524590164 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 30, 'rf_max_depth': 2}. Best is trial 0 with value: 0.7335504885993486.
# [I 2025-08-04 23:05:07,439] Trial 2 finished with value: 0.7360472751149048 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.12140018454869156, 'gb_n_estimators': 350, 'gb_subsample': 1.0, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 6}. Best is trial 2 with value: 0.7360472751149048.
# [I 2025-08-04 23:05:08,337] Trial 3 finished with value: 0.7465181058495822 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.00897305353232198, 'gb_n_estimators': 200, 'gb_subsample': 0.9, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 2}. Best is trial 3 with value: 0.7465181058495822.
# [I 2025-08-04 23:05:08,722] Trial 4 finished with value: 0.7084846483988115 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.2666804337948426, 'gb_n_estimators': 200, 'gb_subsample': 0.5, 'gb_criterion': 'squared_error', 'gb_max_depth': 13}. Best is trial 3 with value: 0.7465181058495822.
# [I 2025-08-04 23:05:08,754] Trial 5 finished with value: 0.7374554872126902 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 10, 'rf_max_depth': 8}. Best is trial 3 with value: 0.7465181058495822.
# [I 2025-08-04 23:05:08,809] Trial 6 finished with value: 0.7278688524590164 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.3167789171732337, 'gb_n_estimators': 200, 'gb_subsample': 0.2, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 4}. Best is trial 3 with value: 0.7465181058495822.
# [I 2025-08-04 23:05:09,667] Trial 7 finished with value: 0.7495395948434622 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002840659539422111, 'gb_n_estimators': 500, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 2}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:10,118] Trial 8 finished with value: 0.7387446598751233 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.08891349940375345, 'gb_n_estimators': 500, 'gb_subsample': 0.6, 'gb_criterion': 'squared_error', 'gb_max_depth': 7}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:10,168] Trial 9 finished with value: 0.744920993227991 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 20, 'rf_max_depth': 6}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:21,157] Trial 10 finished with value: 0.7403062886933854 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.0010497751583031492, 'gb_n_estimators': 500, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 29}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:21,635] Trial 11 finished with value: 0.7452631578947368 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.005034498348072617, 'gb_n_estimators': 100, 'gb_subsample': 1.0, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 2}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:22,992] Trial 12 finished with value: 0.7413793103448276 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.00838622272338162, 'gb_n_estimators': 350, 'gb_subsample': 0.7000000000000001, 'gb_criterion': 'squared_error', 'gb_max_depth': 2}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:23,137] Trial 13 finished with value: 0.7452631578947368 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.00791403079071572, 'gb_n_estimators': 50, 'gb_subsample': 0.4, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 2}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:25,341] Trial 14 finished with value: 0.7371150729335494 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0012772370873043038, 'gb_n_estimators': 300, 'gb_subsample': 0.8, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:25,941] Trial 15 finished with value: 0.740909090909091 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.021248660822577252, 'gb_n_estimators': 200, 'gb_subsample': 0.30000000000000004, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 3}. Best is trial 7 with value: 0.7495395948434622.
# [I 2025-08-04 23:05:28,258] Trial 16 finished with value: 0.7503152585119798 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0032051398306569873, 'gb_n_estimators': 400, 'gb_subsample': 0.8, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 16 with value: 0.7503152585119798.
# [I 2025-08-04 23:05:30,631] Trial 17 finished with value: 0.7487373737373737 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002713333172457707, 'gb_n_estimators': 450, 'gb_subsample': 0.7000000000000001, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 16 with value: 0.7503152585119798.
# [I 2025-08-04 23:05:31,211] Trial 18 finished with value: 0.7197600799733422 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 90, 'rf_max_depth': 26}. Best is trial 16 with value: 0.7503152585119798.
# [I 2025-08-04 23:05:33,137] Trial 19 finished with value: 0.7404980340760158 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.02064502964858509, 'gb_n_estimators': 400, 'gb_subsample': 0.5, 'gb_criterion': 'squared_error', 'gb_max_depth': 8}. Best is trial 16 with value: 0.7503152585119798.
# [I 2025-08-04 23:05:33,831] Trial 20 finished with value: 0.7507846829880728 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0027025895307693265, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:34,524] Trial 21 finished with value: 0.7507846829880728 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002716009889995878, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:35,293] Trial 22 finished with value: 0.7503152585119798 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0022235076122607816, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:36,462] Trial 23 finished with value: 0.7470644239923834 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.004231992584482954, 'gb_n_estimators': 400, 'gb_subsample': 0.30000000000000004, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:36,864] Trial 24 finished with value: 0.7335075114304376 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.04306284734987168, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 10}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:38,886] Trial 25 finished with value: 0.7445302445302445 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0013926581666242005, 'gb_n_estimators': 450, 'gb_subsample': 0.30000000000000004, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:39,533] Trial 26 finished with value: 0.722203783604381 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 100, 'rf_max_depth': 29}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:39,644] Trial 27 finished with value: 0.7330226364846871 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.8396750209470852, 'gb_n_estimators': 300, 'gb_subsample': 0.8, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:40,478] Trial 28 finished with value: 0.7428010471204188 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.014093962979997357, 'gb_n_estimators': 350, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:05:40,716] Trial 29 finished with value: 0.7377633711507293 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 70, 'rf_max_depth': 9}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:11,241] Trial 30 finished with value: 0.7324777887462981 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.004544106355660697, 'gb_n_estimators': 450, 'gb_subsample': 0.4, 'gb_criterion': 'squared_error', 'gb_max_depth': 20}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:12,014] Trial 31 finished with value: 0.7501577287066246 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002215394341853249, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:12,634] Trial 32 finished with value: 0.7492992837122392 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.001972700448908405, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:13,893] Trial 33 finished with value: 0.7434991974317817 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.003929161196160609, 'gb_n_estimators': 450, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:14,779] Trial 34 finished with value: 0.748178650617675 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0018317294389898686, 'gb_n_estimators': 350, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:15,900] Trial 35 finished with value: 0.7416531604538088 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.00669918711891353, 'gb_n_estimators': 500, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:15,999] Trial 36 finished with value: 0.7337895079830564 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 50, 'rf_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:17,798] Trial 37 finished with value: 0.7465731590691743 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002971011533049233, 'gb_n_estimators': 400, 'gb_subsample': 0.4, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:20,927] Trial 38 finished with value: 0.7417992854822995 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0010033306358528456, 'gb_n_estimators': 350, 'gb_subsample': 0.6, 'gb_criterion': 'squared_error', 'gb_max_depth': 6}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:24,502] Trial 39 finished with value: 0.73828125 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0018320860959535079, 'gb_n_estimators': 300, 'gb_subsample': 0.9, 'gb_criterion': 'squared_error', 'gb_max_depth': 6}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:24,876] Trial 40 finished with value: 0.7305034550839091 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 70, 'rf_max_depth': 15}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:25,647] Trial 41 finished with value: 0.7493686868686869 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0024509339551941436, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:26,730] Trial 42 finished with value: 0.7456966547580384 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.005571596246889011, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:27,500] Trial 43 finished with value: 0.7354670150228608 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.01285496064112343, 'gb_n_estimators': 400, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:28,415] Trial 44 finished with value: 0.7453851050286442 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0032246946368824623, 'gb_n_estimators': 250, 'gb_subsample': 0.30000000000000004, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:30,332] Trial 45 finished with value: 0.7453255963894262 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0017353463381860734, 'gb_n_estimators': 350, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 8}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:31,731] Trial 46 finished with value: 0.7441562600064041 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0033415041257850464, 'gb_n_estimators': 500, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:32,303] Trial 47 finished with value: 0.7462974887314875 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.010607374957591982, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 2}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:37,378] Trial 48 finished with value: 0.7359477124183007 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002296812402923377, 'gb_n_estimators': 400, 'gb_subsample': 1.0, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 6}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:55,692] Trial 49 finished with value: 0.7412724306688417 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.001426504501809849, 'gb_n_estimators': 500, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 17}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:55,753] Trial 50 finished with value: 0.7339449541284404 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 30, 'rf_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:56,364] Trial 51 finished with value: 0.748730964467005 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.005798842020570251, 'gb_n_estimators': 500, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 2}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:57,237] Trial 52 finished with value: 0.7488584474885844 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0024294454592233184, 'gb_n_estimators': 500, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 2}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:58,252] Trial 53 finished with value: 0.7477763659466328 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.004016307961874978, 'gb_n_estimators': 450, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:58,845] Trial 54 finished with value: 0.7441300421432872 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0013023565620347154, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 2}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:59,143] Trial 55 finished with value: 0.7433801896044459 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.16787581107426547, 'gb_n_estimators': 500, 'gb_subsample': 0.7000000000000001, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:06:59,574] Trial 56 finished with value: 0.7332892124420913 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.05333370232332588, 'gb_n_estimators': 150, 'gb_subsample': 0.30000000000000004, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:00,556] Trial 57 finished with value: 0.7414921465968587 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.007513774010166219, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:12,128] Trial 58 finished with value: 0.737565445026178 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.003099663321405777, 'gb_n_estimators': 350, 'gb_subsample': 0.5, 'gb_criterion': 'squared_error', 'gb_max_depth': 12}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:18,115] Trial 59 finished with value: 0.741514360313316 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.005133257195457115, 'gb_n_estimators': 450, 'gb_subsample': 0.8, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 7}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:18,495] Trial 60 finished with value: 0.730844793713163 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 80, 'rf_max_depth': 13}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:19,270] Trial 61 finished with value: 0.7493686868686869 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0023549295351891607, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:20,045] Trial 62 finished with value: 0.7500785916378497 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.001526472975639107, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:28,775] Trial 63 finished with value: 0.743431722348362 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0015826704203021835, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 29}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:29,793] Trial 64 finished with value: 0.7479674796747967 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0010114568483424937, 'gb_n_estimators': 450, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:31,017] Trial 65 finished with value: 0.7453135100193924 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.003698623584592535, 'gb_n_estimators': 500, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:31,589] Trial 66 finished with value: 0.7484355444305382 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0019860164400327986, 'gb_n_estimators': 250, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:35,727] Trial 67 finished with value: 0.7439143135345667 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0013039319691905058, 'gb_n_estimators': 450, 'gb_subsample': 0.30000000000000004, 'gb_criterion': 'squared_error', 'gb_max_depth': 8}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:38,132] Trial 68 finished with value: 0.7417688831504197 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0026534687697512263, 'gb_n_estimators': 400, 'gb_subsample': 0.6, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:38,277] Trial 69 finished with value: 0.7403783431180692 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.640821028957038, 'gb_n_estimators': 50, 'gb_subsample': 0.9, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:38,619] Trial 70 finished with value: 0.7420814479638009 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.021160583207332075, 'gb_n_estimators': 350, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 2}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:39,397] Trial 71 finished with value: 0.7493686868686869 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0024562645409317778, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:40,418] Trial 72 finished with value: 0.7494442680215941 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0021251289555648985, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:41,694] Trial 73 finished with value: 0.7468030690537084 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0016833147829853387, 'gb_n_estimators': 350, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:43,123] Trial 74 finished with value: 0.7455887070901508 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0020472197037040706, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 6}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:45,392] Trial 75 finished with value: 0.7448186528497409 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0040090523134234755, 'gb_n_estimators': 400, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 7}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:45,564] Trial 76 finished with value: 0.7408360128617363 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 100, 'rf_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:46,992] Trial 77 finished with value: 0.7453733248245055 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0011571881478005812, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 6}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:47,727] Trial 78 finished with value: 0.7499207606973058 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002857250485284896, 'gb_n_estimators': 300, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:49,312] Trial 79 finished with value: 0.7461636828644501 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.004636275532346576, 'gb_n_estimators': 300, 'gb_subsample': 0.5, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:49,859] Trial 80 finished with value: 0.7479521109010712 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.006796123268511085, 'gb_n_estimators': 150, 'gb_subsample': 0.4, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:50,718] Trial 81 finished with value: 0.7488061127029608 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0031078851516854037, 'gb_n_estimators': 350, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:51,697] Trial 82 finished with value: 0.7480964467005076 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0016431145102618816, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:53,028] Trial 83 finished with value: 0.744426494345719 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002809016189142898, 'gb_n_estimators': 300, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 6}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:53,898] Trial 84 finished with value: 0.7493686868686869 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0020919436109803694, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:54,929] Trial 85 finished with value: 0.7394848386044995 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.009084171081429235, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 7}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:59,709] Trial 86 finished with value: 0.743547860176413 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0035386741140174868, 'gb_n_estimators': 500, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 9}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:07:59,942] Trial 87 finished with value: 0.7251153592617007 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 40, 'rf_max_depth': 17}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:00,801] Trial 88 finished with value: 0.7484157160963245 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0013140891948670407, 'gb_n_estimators': 350, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:10,079] Trial 89 finished with value: 0.7453658536585366 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.005876259249211436, 'gb_n_estimators': 400, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 17}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:13,122] Trial 90 finished with value: 0.7420083952211818 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'log_loss', 'gb_learning_rate': 0.0027630176780048133, 'gb_n_estimators': 450, 'gb_subsample': 0.7000000000000001, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:13,896] Trial 91 finished with value: 0.7492904446546831 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0021264263052529755, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 4}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:14,755] Trial 92 finished with value: 0.7486529318541997 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.001661742116686425, 'gb_n_estimators': 350, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 5}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:15,375] Trial 93 finished with value: 0.7505463627848892 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.002486463782281907, 'gb_n_estimators': 400, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:16,073] Trial 94 finished with value: 0.7477707006369426 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.004528597934753705, 'gb_n_estimators': 450, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:16,466] Trial 95 finished with value: 0.75 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0033912186174783732, 'gb_n_estimators': 250, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:17,036] Trial 96 finished with value: 0.7492957746478873 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0035551847413244245, 'gb_n_estimators': 250, 'gb_subsample': 0.2, 'gb_criterion': 'squared_error', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:17,431] Trial 97 finished with value: 0.7497662823309442 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0030261833358062452, 'gb_n_estimators': 250, 'gb_subsample': 0.1, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:21,653] Trial 98 finished with value: 0.7460265974699968 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0029694962626580154, 'gb_n_estimators': 200, 'gb_subsample': 0.1, 'gb_criterion': 'squared_error', 'gb_max_depth': 26}. Best is trial 20 with value: 0.7507846829880728.
# [I 2025-08-04 23:08:21,937] Trial 99 finished with value: 0.7377748605185428 and parameters: {'classifier': 'GradientBoosting', 'gb_loss': 'exponential', 'gb_learning_rate': 0.0378979565200093, 'gb_n_estimators': 250, 'gb_subsample': 0.1, 'gb_criterion': 'friedman_mse', 'gb_max_depth': 3}. Best is trial 20 with value: 0.7507846829880728.

# %%
study.best_params
# Out:
# {'classifier': 'GradientBoosting',
#  'gb_loss': 'exponential',
#  'gb_learning_rate': 0.0027025895307693265,
#  'gb_n_estimators': 450,
#  'gb_subsample': 0.1,
#  'gb_criterion': 'squared_error',
#  'gb_max_depth': 3}

# %%
if study.best_params['classifier'] == 'GradientBoosting':
    gb_optuna = GradientBoostingClassifier(
        loss=study.best_params['gb_loss'],
        learning_rate=study.best_params['gb_learning_rate'],
        n_estimators=study.best_params['gb_n_estimators'],
        subsample=study.best_params['gb_subsample'],
        criterion=study.best_params['gb_criterion'],
        max_depth=study.best_params['gb_max_depth'],
        random_state=random_state,
        validation_fraction=0.1,
        n_iter_no_change=10
    )
    gb_optuna.fit(X_train, y_train)
    y_pred = gb_optuna.predict(X_val)
else:
    rf_optuna = RandomForestClassifier(
        max_depth=study.best_params['rf_max_depth'],
        n_estimators=study.best_params['rf_n_estimators'],
        random_state=random_state
    )
    rf_optuna.fit(X_train, y_train)
    y_pred = rf_optuna.predict(X_val)

print("Accuracy:", accuracy_score(y_val, y_pred))
print("Classification Report:\n", classification_report(y_val, y_pred))
print("Recall Score:", recall_score(y_val, y_pred))
print("F1 Score:", f1_score(y_val, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))
# Out:
# Accuracy: 0.7345369441658308
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.66      0.72      1514
#            1       0.70      0.81      0.75      1477
#
#     accuracy                           0.73      2991
#    macro avg       0.74      0.74      0.73      2991
# weighted avg       0.74      0.73      0.73      2991
#
# Recall Score: 0.8097494922139472
# F1 Score: 0.7507846829880728
# Confusion Matrix:
#  [[1001  513]
#  [ 281 1196]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(y_val, y_pred, cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
if study.best_params['classifier'] == 'GradientBoosting':
    gb_importance = pd.DataFrame({'feature': pipe_preprocess.get_feature_names_out(), 'importance': gb_optuna.feature_importances_}).sort_values(by='importance', ascending=False)[:10]
else:
    rf_importance = pd.DataFrame({'feature': pipe_preprocess.get_feature_names_out(), 'importance': rf_optuna.feature_importances_}).sort_values(by='importance', ascending=False)[:10]

fig, ax = plt.subplots(figsize=(8, 6))
if study.best_params['classifier'] == 'GradientBoosting':
    sns.barplot(gb_importance, x='importance', y='feature', ax=ax)
    plt.title("Top 10 Feature Importances from Gradient Boosting")
else:
    sns.barplot(rf_importance, x='importance', y='feature', ax=ax)
    plt.title("Top 10 Feature Importances from Random Forest")
plt.show()
